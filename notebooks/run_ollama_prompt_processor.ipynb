# %% [markdown]
# #### Startup Ollama

# %%
! curl -fsSL https://ollama.com/install.sh | sh
! sudo apt update
! sudo apt install pciutils lshw
! ollama serve

# %%
! ollama pull llama3.1

# %% [markdown]
# ##### Install parent package

# %%
! pip install -e ..
# Out:
# WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
# Obtaining file:///home/jovyan/shared/renalpa/venv_traceability/aiswre
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
# Building wheels for collected packages: aiswre
#   Building editable for aiswre (pyproject.toml) ... done
#   Created wheel for aiswre: filename=aiswre-0.0.1-0.editable-py3-none-any.whl size=15310 sha256=bb2fe3804c389560a70a0d0dcd37b5012c2d5c0e9ca8d2c3e29e86bde8863569
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ejzq4uu9/wheels/e7/f5/79/e92046896865d1207d1c49bf6bcbb53bd2735f87b6d33fb7b0
# Successfully built aiswre
# WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
# Installing collected packages: aiswre
#   Attempting uninstall: aiswre
#     WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
#     Found existing installation: aiswre 0.0.1
#     Uninstalling aiswre-0.0.1:
#       Successfully uninstalled aiswre-0.0.1
# WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
# Successfully installed aiswre-0.0.1
# WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -angchain (/home/jovyan/shared/renalpa/venv_traceability/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ##### Import class to run ollama prompts

# %%
import src

# %%
from scripts.ollama_prompt_processor_rag import RAGProcessor, PromptProcessor

# %% [markdown]
# ##### Create / load data

# %% [markdown]
# ##### Define inputs

# %% [markdown]
# ##### Run prompt

# %%
asyncio.run(main(
    input_file=input_file,
    output_dir=output_dir,
    output_file=output_file,
    model=model,
    system_message=system_message,
    user_message=user_message,
    column_mapping=column_mapping,
    prompt_vars=prompt_vars
    )
)
